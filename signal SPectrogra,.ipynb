# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import os
# %matplotlib inline

# %%
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=1/'
files_s1 = []
for r,d,f in os.walk(path):
    files_s1.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=2/'
files_s2 = []
for r,d,f in os.walk(path):
    files_s2.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=3/'
files_s3 = []
for r,d,f in os.walk(path):
    files_s3.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=4/'
files_s4 = []
for r,d,f in os.walk(path):
    files_s4.append(f)

# %%
df_s1 = []
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=1/'
for r,d,f in os.walk(path):
    df_s1.append(f)
for i in range(len(df_s1[0])):
    p = (r+f[i])
    df_s1.append(p)
df_s1 = pd.DataFrame(df_s1[1:],columns=['path'])
df_s1['signal'] = 1

# %%
s2 = []
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=2/'
for r,d,f in os.walk(path):
    s2.append(f)
for i in range(len(s2[0])):
    p = (r+f[i])
    s2.append(p)
df_s2 = pd.DataFrame(s2[1:],columns=['path'])
df_s2['signal'] = 2

# %%
s3 = []
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=3/'
for r,d,f in os.walk(path):
    s3.append(f)
for i in range(len(s3[0])):
    p = (r+f[i])
    s3.append(p)
df_s3 = pd.DataFrame(s3[1:],columns=['path'])
df_s3['signal'] = 3

# %%
s4 = []
path = '/Users/sanjeevkumar/Desktop/MIX DATA Signal/S=4/'
for r,d,f in os.walk(path):
    s4.append(f)
for i in range(len(s4[0])):
    p = (r+f[i])
    s4.append(p)
df_s4 = pd.DataFrame(s4[1:],columns=['path'])
df_s4['signal'] = 4

# %%
df_s_all = [df_s1,df_s2,df_s3,df_s4]
df = pd.concat(df_s_all)

# %%
df=df.reset_index(drop=True)

# %%
pd.DataFrame(df.index).duplicated().sum()
# Out:
# 0

# %%
df['signal'].value_counts()
# Out:
# 4    123
# 3    118
# 1    117
# 2    114
# Name: signal, dtype: int64

# %%
import librosa.display
y,sr = librosa.load(df['path'][17],res_type = 'kaiser_fast')
plt.figure()
plt.subplot(1,1,1)
librosa.display.waveplot(y,sr=sr)

# %%
x,sr = librosa.load(df['path'][17],res_type = 'kaiser_fast')

X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
plt.imshow(Xdb)
plt.show()

# %%
def stft_(path):
    X,sample_rate = librosa.load(path,res_type = 'kaiser_fast')
    D = np.abs(librosa.stft(X))**2
    Xdb = librosa.amplitude_to_db(D)
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz')
    plt.colorbar()
df['spect'] = df['path'].apply(stft_)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...
